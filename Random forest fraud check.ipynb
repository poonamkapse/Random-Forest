# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('Fraud_check.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Undergrad        600 non-null    object
#  1   Marital.Status   600 non-null    object
#  2   Taxable.Income   600 non-null    int64
#  3   City.Population  600 non-null    int64
#  4   Work.Experience  600 non-null    int64
#  5   Urban            600 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 28.2+ KB

# %%
data.isnull().sum()
# Out:
# Undergrad          0
# Marital.Status     0
# Taxable.Income     0
# City.Population    0
# Work.Experience    0
# Urban              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.rename(columns = {'Marital.Status':'Marital_status', 'Taxable.Income':'Taxable_income','City.Population':'City_population', 'Work.Experience':'Work_experience'}, inplace = True)

# %%
# Converting Sales feature into categorical type
taxable_inc = pd.cut(data.Taxable_income, bins=[0, 30000, 100000], labels=['Risky', 'Good'])
data.drop(['Taxable_income'], axis=1, inplace=True)
data.insert(0, 'Taxable_income', taxable_inc)
data
# Out:
#     Taxable_income Undergrad Marital_status  City_population  Work_experience  \
# 0             Good        NO         Single            50047               10
# 1             Good       YES       Divorced           134075               18
# 2             Good        NO        Married           160205               30
# 3             Good       YES         Single           193264               15
# 4             Good        NO        Married            27533               28
# ..             ...       ...            ...              ...              ...
# 595           Good       YES       Divorced            39492                7
# 596           Good       YES       Divorced            55369                2
# 597           Good        NO       Divorced           154058                0
# 598           Good       YES        Married           180083               17
# 599           Good        NO       Divorced           158137               16
#
#     Urban
# 0     YES
# 1     YES
# 2     YES
# 3     YES
# 4      NO
# ..    ...
# 595   YES
# 596   YES
# 597   YES
# 598    NO
# 599    NO
#
# [600 rows x 6 columns]

# %%
label_en = preprocessing.LabelEncoder()
data['Undergrad'] = label_en.fit_transform(data['Undergrad'])
data.Undergrad
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 595    1
# 596    1
# 597    0
# 598    1
# 599    0
# Name: Undergrad, Length: 600, dtype: int32

# %%
data['Marital_status'] = label_en.fit_transform(data['Marital_status'])
data.Marital_status
# Out:
# 0      2
# 1      0
# 2      1
# 3      2
# 4      1
#       ..
# 595    0
# 596    0
# 597    0
# 598    1
# 599    0
# Name: Marital_status, Length: 600, dtype: int32

# %%
data['Urban'] = label_en.fit_transform(data['Urban'])
data.Urban
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 595    1
# 596    1
# 597    1
# 598    0
# 599    0
# Name: Urban, Length: 600, dtype: int32

# %%
from sklearn.ensemble import IsolationForest

# %%
df_copy = data.copy()
data_encoded = pd.get_dummies(df_copy)

# %%
# training the isolation forest model
clf = IsolationForest(random_state=10, contamination=.01)
clf.fit(data_encoded)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.01, random_state=10)

# %%
# predictions
y_pred_outliers = clf.predict(data_encoded)
data_encoded
# Out:
#      Undergrad  Marital_status  City_population  Work_experience  Urban  \
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
#      Taxable_income_Risky  Taxable_income_Good
# 0                       0                    1
# 1                       0                    1
# 2                       0                    1
# 3                       0                    1
# 4                       0                    1
# ..                    ...                  ...
# 595                     0                    1
# 596                     0                    1
# 597                     0                    1
# 598                     0                    1
# 599                     0                    1
#
# [600 rows x 7 columns]

# %%
data_encoded['scores'] = clf.decision_function(data_encoded)
data_encoded['anomaly'] = clf.predict(data_encoded.iloc[:, 0:7])
data_encoded
# Out:
#      Undergrad  Marital_status  City_population  Work_experience  Urban  \
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
#      Taxable_income_Risky  Taxable_income_Good    scores  anomaly
# 0                       0                    1  0.128597        1
# 1                       0                    1  0.131005        1
# 2                       0                    1  0.084827        1
# 3                       0                    1  0.104186        1
# 4                       0                    1  0.097489        1
# ..                    ...                  ...       ...      ...
# 595                     0                    1  0.095277        1
# 596                     0                    1  0.075817        1
# 597                     0                    1  0.067130        1
# 598                     0                    1  0.141565        1
# 599                     0                    1  0.130338        1
#
# [600 rows x 9 columns]

# %%
# Print the outlier data points
data_encoded[data_encoded['anomaly']==-1]
# Out:
#      Undergrad  Marital_status  City_population  Work_experience  Urban  \
# 16           1               0            34551               29      0
# 34           1               0           183767                1      1
# 126          1               0           195022                3      1
# 168          0               0           167629               30      0
# 280          0               0            33184                1      0
# 541          1               0           191874               30      1
#
#      Taxable_income_Risky  Taxable_income_Good    scores  anomaly
# 16                      1                    0 -0.005177       -1
# 34                      1                    0 -0.016414       -1
# 126                     1                    0 -0.016731       -1
# 168                     1                    0 -0.002113       -1
# 280                     1                    0 -0.022976       -1
# 541                     1                    0 -0.006491       -1

# %%
data.drop([16, 34, 126, 168, 280, 541], inplace=True)
data
# Out:
#     Taxable_income  Undergrad  Marital_status  City_population  \
# 0             Good          0               2            50047
# 1             Good          1               0           134075
# 2             Good          0               1           160205
# 3             Good          1               2           193264
# 4             Good          0               1            27533
# ..             ...        ...             ...              ...
# 595           Good          1               0            39492
# 596           Good          1               0            55369
# 597           Good          0               0           154058
# 598           Good          1               1           180083
# 599           Good          0               0           158137
#
#      Work_experience  Urban
# 0                 10      1
# 1                 18      1
# 2                 30      1
# 3                 15      1
# 4                 28      0
# ..               ...    ...
# 595                7      1
# 596                2      1
# 597                0      1
# 598               17      0
# 599               16      0
#
# [594 rows x 6 columns]

# %%
#Model building (Random Forest)
# Splitting data into feature and class
X = data.iloc[:,1:]
Y = data.iloc[:,0]
Y
# Out:
# 0      Good
# 1      Good
# 2      Good
# 3      Good
# 4      Good
#        ...
# 595    Good
# 596    Good
# 597    Good
# 598    Good
# 599    Good
# Name: Taxable_income, Length: 594, dtype: category
# Categories (2, object): ['Risky' < 'Good']

# %%
X
# Out:
#      Undergrad  Marital_status  City_population  Work_experience  Urban
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
# [594 rows x 5 columns]

# %%
# Split the data into train and test dataset
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, stratify=Y)

# %%
# Model building
num_trees = 100
max_features = 2
kfold = KFold(n_splits=10, random_state=7, shuffle=True)
model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features, oob_score=True)
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.7609039548022598

# %%
# for accuracy

model.fit(x_train, y_train)
pred = model.predict(x_train)
accuracy = accuracy_score(y_train, pred)
accuracy
# Out:
# 1.0

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_train, pred)
confusion
# Out:
# array([[381,   0],
#        [  0,  94]], dtype=int64)

# %%
##Prediction on test data
pred_test = model.predict(x_test)
acc_test = accuracy_score(y_test, pred_test)
acc_test
# Out:
# 0.7563025210084033

# %%
fig = plt.figure(figsize=(15, 10))

fn = [ 'Undergrad', 'Marital_status', 'City.Population',
       'Work.Experience', 'Urban']
cn = ['Risky', 'Good']

plot_tree(model.estimators_[0], 
          feature_names=fn,
          class_names=cn, 
          filled=True, impurity=True, 
          rounded=True)
# Out:
# [Text(0.36398467432950193, 0.9666666666666667, 'Work.Experience <= 6.5\ngini = 0.317\nsamples = 300\nvalue = [381, 94]\nclass = Risky'),
#  Text(0.09003831417624521, 0.9, 'City.Population <= 176182.0\ngini = 0.198\nsamples = 61\nvalue = [88, 11]\nclass = Risky'),
#  Text(0.04980842911877394, 0.8333333333333334, 'Marital_status <= 0.5\ngini = 0.173\nsamples = 57\nvalue = [85, 9]\nclass = Risky'),
#  Text(0.01532567049808429, 0.7666666666666667, 'City.Population <= 87052.5\ngini = 0.095\nsamples = 14\nvalue = [19, 1]\nclass = Risky'),
#  Text(0.007662835249042145, 0.7, 'gini = 0.0\nsamples = 7\nvalue = [11, 0]\nclass = Risky'),
#  Text(0.022988505747126436, 0.7, 'Urban <= 0.5\ngini = 0.198\nsamples = 7\nvalue = [8, 1]\nclass = Risky'),
#  Text(0.01532567049808429, 0.6333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [5, 0]\nclass = Risky'),
#  Text(0.03065134099616858, 0.6333333333333333, 'Work.Experience <= 2.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.022988505747126436, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.038314176245210725, 0.5666666666666667, 'Undergrad <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.03065134099616858, 0.5, 'City.Population <= 123844.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.022988505747126436, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.038314176245210725, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.04597701149425287, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.0842911877394636, 0.7666666666666667, 'Work.Experience <= 0.5\ngini = 0.193\nsamples = 43\nvalue = [66, 8]\nclass = Risky'),
#  Text(0.07662835249042145, 0.7, 'gini = 0.0\nsamples = 6\nvalue = [12, 0]\nclass = Risky'),
#  Text(0.09195402298850575, 0.7, 'Work.Experience <= 1.5\ngini = 0.225\nsamples = 37\nvalue = [54, 8]\nclass = Risky'),
#  Text(0.06130268199233716, 0.6333333333333333, 'Urban <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.05363984674329502, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.06896551724137931, 0.5666666666666667, 'City.Population <= 76754.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.06130268199233716, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.07662835249042145, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.12260536398467432, 0.6333333333333333, 'Marital_status <= 1.5\ngini = 0.209\nsamples = 34\nvalue = [52, 7]\nclass = Risky'),
#  Text(0.09961685823754789, 0.5666666666666667, 'City.Population <= 61580.5\ngini = 0.266\nsamples = 13\nvalue = [16, 3]\nclass = Risky'),
#  Text(0.09195402298850575, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.10727969348659004, 0.5, 'Work.Experience <= 4.5\ngini = 0.32\nsamples = 10\nvalue = [12, 3]\nclass = Risky'),
#  Text(0.09961685823754789, 0.43333333333333335, 'City.Population <= 80775.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Good'),
#  Text(0.09195402298850575, 0.36666666666666664, 'City.Population <= 66115.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.0842911877394636, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.09961685823754789, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.10727969348659004, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Good'),
#  Text(0.11494252873563218, 0.43333333333333335, 'gini = 0.0\nsamples = 6\nvalue = [11, 0]\nclass = Risky'),
#  Text(0.14559386973180077, 0.5666666666666667, 'Undergrad <= 0.5\ngini = 0.18\nsamples = 21\nvalue = [36, 4]\nclass = Risky'),
#  Text(0.13793103448275862, 0.5, 'City.Population <= 120802.0\ngini = 0.26\nsamples = 13\nvalue = [22, 4]\nclass = Risky'),
#  Text(0.13026819923371646, 0.43333333333333335, 'gini = 0.0\nsamples = 9\nvalue = [16, 0]\nclass = Risky'),
#  Text(0.14559386973180077, 0.43333333333333335, 'City.Population <= 130163.5\ngini = 0.48\nsamples = 4\nvalue = [6, 4]\nclass = Risky'),
#  Text(0.13793103448275862, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.1532567049808429, 0.36666666666666664, 'City.Population <= 138632.0\ngini = 0.375\nsamples = 3\nvalue = [6, 2]\nclass = Risky'),
#  Text(0.14559386973180077, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.16091954022988506, 0.3, 'Urban <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [2, 2]\nclass = Risky'),
#  Text(0.1532567049808429, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.1685823754789272, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.1532567049808429, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [14, 0]\nclass = Risky'),
#  Text(0.13026819923371646, 0.8333333333333334, 'Urban <= 0.5\ngini = 0.48\nsamples = 4\nvalue = [3, 2]\nclass = Risky'),
#  Text(0.11494252873563218, 0.7666666666666667, 'Undergrad <= 0.5\ngini = 0.444\nsamples = 2\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.10727969348659004, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.12260536398467432, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.14559386973180077, 0.7666666666666667, 'City.Population <= 195708.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.13793103448275862, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.1532567049808429, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.6379310344827587, 0.9, 'Urban <= 0.5\ngini = 0.344\nsamples = 239\nvalue = [293, 83]\nclass = Risky'),
#  Text(0.4085249042145594, 0.8333333333333334, 'Work.Experience <= 11.5\ngini = 0.317\nsamples = 124\nvalue = [150, 37]\nclass = Risky'),
#  Text(0.27011494252873564, 0.7666666666666667, 'Undergrad <= 0.5\ngini = 0.449\nsamples = 32\nvalue = [33, 17]\nclass = Risky'),
#  Text(0.23371647509578544, 0.7, 'Marital_status <= 1.5\ngini = 0.491\nsamples = 17\nvalue = [13, 10]\nclass = Risky'),
#  Text(0.20689655172413793, 0.6333333333333333, 'Work.Experience <= 10.5\ngini = 0.459\nsamples = 11\nvalue = [9, 5]\nclass = Risky'),
#  Text(0.19157088122605365, 0.5666666666666667, 'Work.Experience <= 9.5\ngini = 0.397\nsamples = 8\nvalue = [8, 3]\nclass = Risky'),
#  Text(0.1839080459770115, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.19923371647509577, 0.5, 'Marital_status <= 0.5\ngini = 0.42\nsamples = 7\nvalue = [7, 3]\nclass = Risky'),
#  Text(0.19157088122605365, 0.43333333333333335, 'City.Population <= 171288.0\ngini = 0.469\nsamples = 5\nvalue = [5, 3]\nclass = Risky'),
#  Text(0.1839080459770115, 0.36666666666666664, 'City.Population <= 90527.0\ngini = 0.278\nsamples = 4\nvalue = [5, 1]\nclass = Risky'),
#  Text(0.17624521072796934, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.19157088122605365, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [5, 0]\nclass = Risky'),
#  Text(0.19923371647509577, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.20689655172413793, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.2222222222222222, 0.5666666666666667, 'City.Population <= 71349.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Good'),
#  Text(0.21455938697318008, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.22988505747126436, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Good'),
#  Text(0.26053639846743293, 0.6333333333333333, 'City.Population <= 143087.0\ngini = 0.494\nsamples = 6\nvalue = [4, 5]\nclass = Good'),
#  Text(0.25287356321839083, 0.5666666666666667, 'City.Population <= 40990.0\ngini = 0.32\nsamples = 4\nvalue = [4, 1]\nclass = Risky'),
#  Text(0.24521072796934865, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.26053639846743293, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.2681992337164751, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]\nclass = Good'),
#  Text(0.3065134099616858, 0.7, 'Work.Experience <= 7.5\ngini = 0.384\nsamples = 15\nvalue = [20, 7]\nclass = Risky'),
#  Text(0.29118773946360155, 0.6333333333333333, 'City.Population <= 168002.5\ngini = 0.444\nsamples = 4\nvalue = [4, 2]\nclass = Risky'),
#  Text(0.2835249042145594, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Good'),
#  Text(0.2988505747126437, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.3218390804597701, 0.6333333333333333, 'City.Population <= 49488.0\ngini = 0.363\nsamples = 11\nvalue = [16, 5]\nclass = Risky'),
#  Text(0.31417624521072796, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.32950191570881227, 0.5666666666666667, 'Marital_status <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [16, 4]\nclass = Risky'),
#  Text(0.3218390804597701, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [8, 0]\nclass = Risky'),
#  Text(0.3371647509578544, 0.5, 'City.Population <= 118013.0\ngini = 0.444\nsamples = 7\nvalue = [8, 4]\nclass = Risky'),
#  Text(0.32950191570881227, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.3448275862068966, 0.43333333333333335, 'Work.Experience <= 9.0\ngini = 0.32\nsamples = 6\nvalue = [8, 2]\nclass = Risky'),
#  Text(0.3371647509578544, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [5, 0]\nclass = Risky'),
#  Text(0.3524904214559387, 0.36666666666666664, 'Marital_status <= 1.5\ngini = 0.48\nsamples = 3\nvalue = [3, 2]\nclass = Risky'),
#  Text(0.3448275862068966, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.36015325670498083, 0.3, 'City.Population <= 155656.0\ngini = 0.375\nsamples = 2\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.3524904214559387, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.367816091954023, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.5469348659003831, 0.7666666666666667, 'Work.Experience <= 25.5\ngini = 0.249\nsamples = 92\nvalue = [117, 20]\nclass = Risky'),
#  Text(0.4789272030651341, 0.7, 'Undergrad <= 0.5\ngini = 0.19\nsamples = 62\nvalue = [84, 10]\nclass = Risky'),
#  Text(0.4444444444444444, 0.6333333333333333, 'Work.Experience <= 20.5\ngini = 0.283\nsamples = 30\nvalue = [34, 7]\nclass = Risky'),
#  Text(0.4367816091954023, 0.5666666666666667, 'Work.Experience <= 16.5\ngini = 0.384\nsamples = 20\nvalue = [20, 7]\nclass = Risky'),
#  Text(0.4061302681992337, 0.5, 'Work.Experience <= 14.5\ngini = 0.231\nsamples = 13\nvalue = [13, 2]\nclass = Risky'),
#  Text(0.39846743295019155, 0.43333333333333335, 'Work.Experience <= 13.5\ngini = 0.298\nsamples = 9\nvalue = [9, 2]\nclass = Risky'),
#  Text(0.3831417624521073, 0.36666666666666664, 'City.Population <= 67115.5\ngini = 0.198\nsamples = 7\nvalue = [8, 1]\nclass = Risky'),
#  Text(0.37547892720306514, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.39080459770114945, 0.3, 'Work.Experience <= 12.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Risky'),
#  Text(0.3831417624521073, 0.23333333333333334, 'City.Population <= 98457.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.37547892720306514, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.39080459770114945, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.39846743295019155, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.41379310344827586, 0.36666666666666664, 'City.Population <= 135756.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.4061302681992337, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.421455938697318, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.41379310344827586, 0.43333333333333335, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.4674329501915709, 0.5, 'Marital_status <= 0.5\ngini = 0.486\nsamples = 7\nvalue = [7, 5]\nclass = Risky'),
#  Text(0.4521072796934866, 0.43333333333333335, 'Work.Experience <= 18.5\ngini = 0.49\nsamples = 3\nvalue = [3, 4]\nclass = Good'),
#  Text(0.4444444444444444, 0.36666666666666664, 'City.Population <= 165823.0\ngini = 0.5\nsamples = 2\nvalue = [3, 3]\nclass = Risky'),
#  Text(0.4367816091954023, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]\nclass = Good'),
#  Text(0.4521072796934866, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.45977011494252873, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.4827586206896552, 0.43333333333333335, 'City.Population <= 100848.0\ngini = 0.32\nsamples = 4\nvalue = [4, 1]\nclass = Risky'),
#  Text(0.47509578544061304, 0.36666666666666664, 'Work.Experience <= 18.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.4674329501915709, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.4827586206896552, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.4904214559386973, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.4521072796934866, 0.5666666666666667, 'gini = 0.0\nsamples = 10\nvalue = [14, 0]\nclass = Risky'),
#  Text(0.5134099616858238, 0.6333333333333333, 'Marital_status <= 0.5\ngini = 0.107\nsamples = 32\nvalue = [50, 3]\nclass = Risky'),
#  Text(0.5057471264367817, 0.5666666666666667, 'gini = 0.0\nsamples = 11\nvalue = [18, 0]\nclass = Risky'),
#  Text(0.5210727969348659, 0.5666666666666667, 'Work.Experience <= 14.5\ngini = 0.157\nsamples = 21\nvalue = [32, 3]\nclass = Risky'),
#  Text(0.5134099616858238, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [6, 0]\nclass = Risky'),
#  Text(0.5287356321839081, 0.5, 'Work.Experience <= 24.0\ngini = 0.185\nsamples = 18\nvalue = [26, 3]\nclass = Risky'),
#  Text(0.5210727969348659, 0.43333333333333335, 'City.Population <= 157649.0\ngini = 0.219\nsamples = 15\nvalue = [21, 3]\nclass = Risky'),
#  Text(0.5057471264367817, 0.36666666666666664, 'City.Population <= 66535.0\ngini = 0.105\nsamples = 11\nvalue = [17, 1]\nclass = Risky'),
#  Text(0.49808429118773945, 0.3, 'City.Population <= 60281.5\ngini = 0.32\nsamples = 4\nvalue = [4, 1]\nclass = Risky'),
#  Text(0.4904214559386973, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.5057471264367817, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.5134099616858238, 0.3, 'gini = 0.0\nsamples = 7\nvalue = [13, 0]\nclass = Risky'),
#  Text(0.5363984674329502, 0.36666666666666664, 'City.Population <= 176190.0\ngini = 0.444\nsamples = 4\nvalue = [4, 2]\nclass = Risky'),
#  Text(0.5287356321839081, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Good'),
#  Text(0.5440613026819924, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.5363984674329502, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [5, 0]\nclass = Risky'),
#  Text(0.6149425287356322, 0.7, 'City.Population <= 78701.0\ngini = 0.357\nsamples = 30\nvalue = [33, 10]\nclass = Risky'),
#  Text(0.60727969348659, 0.6333333333333333, 'gini = 0.0\nsamples = 7\nvalue = [11, 0]\nclass = Risky'),
#  Text(0.6226053639846744, 0.6333333333333333, 'City.Population <= 88183.5\ngini = 0.43\nsamples = 23\nvalue = [22, 10]\nclass = Risky'),
#  Text(0.6149425287356322, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]\nclass = Good'),
#  Text(0.6302681992337165, 0.5666666666666667, 'City.Population <= 134590.5\ngini = 0.366\nsamples = 21\nvalue = [22, 7]\nclass = Risky'),
#  Text(0.5938697318007663, 0.5, 'Marital_status <= 1.5\ngini = 0.48\nsamples = 8\nvalue = [6, 4]\nclass = Risky'),
#  Text(0.5747126436781609, 0.43333333333333335, 'Marital_status <= 0.5\ngini = 0.5\nsamples = 3\nvalue = [2, 2]\nclass = Risky'),
#  Text(0.5670498084291188, 0.36666666666666664, 'Work.Experience <= 27.5\ngini = 0.444\nsamples = 2\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.5593869731800766, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.5747126436781609, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.5823754789272031, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.6130268199233716, 0.43333333333333335, 'Work.Experience <= 29.0\ngini = 0.444\nsamples = 5\nvalue = [4, 2]\nclass = Risky'),
#  Text(0.5977011494252874, 0.36666666666666664, 'City.Population <= 98157.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.5900383141762452, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.6053639846743295, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.6283524904214559, 0.36666666666666664, 'City.Population <= 118071.0\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.6206896551724138, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.6360153256704981, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.6666666666666666, 0.5, 'Undergrad <= 0.5\ngini = 0.266\nsamples = 13\nvalue = [16, 3]\nclass = Risky'),
#  Text(0.6590038314176245, 0.43333333333333335, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.6743295019157088, 0.43333333333333335, 'Work.Experience <= 27.5\ngini = 0.375\nsamples = 9\nvalue = [9, 3]\nclass = Risky'),
#  Text(0.6666666666666666, 0.36666666666666664, 'Work.Experience <= 26.5\ngini = 0.5\nsamples = 4\nvalue = [3, 3]\nclass = Risky'),
#  Text(0.6513409961685823, 0.3, 'Marital_status <= 0.5\ngini = 0.444\nsamples = 2\nvalue = [1, 2]\nclass = Good'),
#  Text(0.6436781609195402, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.6590038314176245, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.6819923371647509, 0.3, 'City.Population <= 182084.5\ngini = 0.444\nsamples = 2\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.6743295019157088, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.6896551724137931, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.6819923371647509, 0.36666666666666664, 'gini = 0.0\nsamples = 5\nvalue = [6, 0]\nclass = Risky'),
#  Text(0.8673371647509579, 0.8333333333333334, 'City.Population <= 142117.0\ngini = 0.368\nsamples = 115\nvalue = [143, 46]\nclass = Risky'),
#  Text(0.803639846743295, 0.7666666666666667, 'City.Population <= 140763.5\ngini = 0.425\nsamples = 82\nvalue = [95, 42]\nclass = Risky'),
#  Text(0.7959770114942529, 0.7, 'Marital_status <= 0.5\ngini = 0.413\nsamples = 81\nvalue = [95, 39]\nclass = Risky'),
#  Text(0.735632183908046, 0.6333333333333333, 'City.Population <= 76901.5\ngini = 0.375\nsamples = 23\nvalue = [27, 9]\nclass = Risky'),
#  Text(0.7279693486590039, 0.5666666666666667, 'Work.Experience <= 17.5\ngini = 0.453\nsamples = 16\nvalue = [17, 9]\nclass = Risky'),
#  Text(0.7126436781609196, 0.5, 'Undergrad <= 0.5\ngini = 0.486\nsamples = 5\nvalue = [5, 7]\nclass = Good'),
#  Text(0.7049808429118773, 0.43333333333333335, 'Work.Experience <= 15.5\ngini = 0.494\nsamples = 3\nvalue = [5, 4]\nclass = Risky'),
#  Text(0.6973180076628352, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [5, 0]\nclass = Risky'),
#  Text(0.7126436781609196, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 4]\nclass = Good'),
#  Text(0.7203065134099617, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]\nclass = Good'),
#  Text(0.7432950191570882, 0.5, 'City.Population <= 68622.5\ngini = 0.245\nsamples = 11\nvalue = [12, 2]\nclass = Risky'),
#  Text(0.735632183908046, 0.43333333333333335, 'gini = 0.0\nsamples = 8\nvalue = [11, 0]\nclass = Risky'),
#  Text(0.7509578544061303, 0.43333333333333335, 'Undergrad <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Good'),
#  Text(0.7432950191570882, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.7586206896551724, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Good'),
#  Text(0.7432950191570882, 0.5666666666666667, 'gini = 0.0\nsamples = 7\nvalue = [10, 0]\nclass = Risky'),
#  Text(0.8563218390804598, 0.6333333333333333, 'Undergrad <= 0.5\ngini = 0.425\nsamples = 58\nvalue = [68, 30]\nclass = Risky'),
#  Text(0.8122605363984674, 0.5666666666666667, 'Marital_status <= 1.5\ngini = 0.494\nsamples = 25\nvalue = [25, 20]\nclass = Risky'),
#  Text(0.789272030651341, 0.5, 'City.Population <= 96192.5\ngini = 0.491\nsamples = 10\nvalue = [13, 10]\nclass = Risky'),
#  Text(0.7816091954022989, 0.43333333333333335, 'Work.Experience <= 21.5\ngini = 0.472\nsamples = 9\nvalue = [13, 8]\nclass = Risky'),
#  Text(0.7739463601532567, 0.36666666666666664, 'Work.Experience <= 16.5\ngini = 0.498\nsamples = 6\nvalue = [9, 8]\nclass = Risky'),
#  Text(0.7662835249042146, 0.3, 'City.Population <= 83394.0\ngini = 0.459\nsamples = 5\nvalue = [9, 5]\nclass = Risky'),
#  Text(0.7586206896551724, 0.23333333333333334, 'Work.Experience <= 13.5\ngini = 0.469\nsamples = 3\nvalue = [3, 5]\nclass = Good'),
#  Text(0.7509578544061303, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.7662835249042146, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 5]\nclass = Good'),
#  Text(0.7739463601532567, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [6, 0]\nclass = Risky'),
#  Text(0.7816091954022989, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]\nclass = Good'),
#  Text(0.789272030651341, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.7969348659003831, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.8352490421455939, 0.5, 'City.Population <= 75654.0\ngini = 0.496\nsamples = 15\nvalue = [12, 10]\nclass = Risky'),
#  Text(0.8122605363984674, 0.43333333333333335, 'Work.Experience <= 18.0\ngini = 0.219\nsamples = 7\nvalue = [7, 1]\nclass = Risky'),
#  Text(0.8045977011494253, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.8199233716475096, 0.36666666666666664, 'Work.Experience <= 23.5\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.8122605363984674, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.8275862068965517, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.8582375478927203, 0.43333333333333335, 'City.Population <= 136890.5\ngini = 0.459\nsamples = 8\nvalue = [5, 9]\nclass = Good'),
#  Text(0.8505747126436781, 0.36666666666666664, 'Work.Experience <= 22.0\ngini = 0.298\nsamples = 6\nvalue = [2, 9]\nclass = Good'),
#  Text(0.842911877394636, 0.3, 'City.Population <= 98875.5\ngini = 0.5\nsamples = 3\nvalue = [2, 2]\nclass = Risky'),
#  Text(0.8352490421455939, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.8505747126436781, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.8582375478927203, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 7]\nclass = Good'),
#  Text(0.8659003831417624, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.9003831417624522, 0.5666666666666667, 'City.Population <= 61737.0\ngini = 0.306\nsamples = 33\nvalue = [43, 10]\nclass = Risky'),
#  Text(0.8812260536398467, 0.5, 'City.Population <= 41619.0\ngini = 0.48\nsamples = 8\nvalue = [9, 6]\nclass = Risky'),
#  Text(0.8735632183908046, 0.43333333333333335, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.8888888888888888, 0.43333333333333335, 'City.Population <= 47632.5\ngini = 0.375\nsamples = 4\nvalue = [2, 6]\nclass = Good'),
#  Text(0.8812260536398467, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]\nclass = Good'),
#  Text(0.896551724137931, 0.36666666666666664, 'Marital_status <= 1.5\ngini = 0.48\nsamples = 3\nvalue = [2, 3]\nclass = Good'),
#  Text(0.8888888888888888, 0.3, 'Work.Experience <= 17.5\ngini = 0.444\nsamples = 2\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.8812260536398467, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.896551724137931, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.9042145593869731, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.9195402298850575, 0.5, 'Work.Experience <= 15.5\ngini = 0.188\nsamples = 25\nvalue = [34, 4]\nclass = Risky'),
#  Text(0.9118773946360154, 0.43333333333333335, 'gini = 0.0\nsamples = 11\nvalue = [17, 0]\nclass = Risky'),
#  Text(0.9272030651340997, 0.43333333333333335, 'Work.Experience <= 16.5\ngini = 0.308\nsamples = 14\nvalue = [17, 4]\nclass = Risky'),
#  Text(0.9195402298850575, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9348659003831418, 0.36666666666666664, 'Work.Experience <= 25.0\ngini = 0.255\nsamples = 13\nvalue = [17, 3]\nclass = Risky'),
#  Text(0.9272030651340997, 0.3, 'Marital_status <= 1.5\ngini = 0.355\nsamples = 9\nvalue = [10, 3]\nclass = Risky'),
#  Text(0.9118773946360154, 0.23333333333333334, 'City.Population <= 88477.0\ngini = 0.48\nsamples = 4\nvalue = [3, 2]\nclass = Risky'),
#  Text(0.9042145593869731, 0.16666666666666666, 'Work.Experience <= 17.5\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.896551724137931, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.9118773946360154, 0.1, 'City.Population <= 73219.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.9042145593869731, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.9195402298850575, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9195402298850575, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9425287356321839, 0.23333333333333334, 'Work.Experience <= 18.5\ngini = 0.219\nsamples = 5\nvalue = [7, 1]\nclass = Risky'),
#  Text(0.9348659003831418, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [5, 0]\nclass = Risky'),
#  Text(0.9501915708812261, 0.16666666666666666, 'Work.Experience <= 19.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.9425287356321839, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9578544061302682, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.9425287356321839, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.8113026819923371, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]\nclass = Good'),
#  Text(0.9310344827586207, 0.7666666666666667, 'Undergrad <= 0.5\ngini = 0.142\nsamples = 33\nvalue = [48, 4]\nclass = Risky'),
#  Text(0.9157088122605364, 0.7, 'City.Population <= 187733.5\ngini = 0.067\nsamples = 17\nvalue = [28, 1]\nclass = Risky'),
#  Text(0.9080459770114943, 0.6333333333333333, 'gini = 0.0\nsamples = 15\nvalue = [27, 0]\nclass = Risky'),
#  Text(0.9233716475095786, 0.6333333333333333, 'Work.Experience <= 20.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.9157088122605364, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.9310344827586207, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.946360153256705, 0.7, 'City.Population <= 164962.5\ngini = 0.227\nsamples = 16\nvalue = [20, 3]\nclass = Risky'),
#  Text(0.9386973180076629, 0.6333333333333333, 'gini = 0.0\nsamples = 5\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.9540229885057471, 0.6333333333333333, 'Work.Experience <= 18.0\ngini = 0.305\nsamples = 11\nvalue = [13, 3]\nclass = Risky'),
#  Text(0.946360153256705, 0.5666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.9616858237547893, 0.5666666666666667, 'Work.Experience <= 20.0\ngini = 0.444\nsamples = 7\nvalue = [6, 3]\nclass = Risky'),
#  Text(0.9540229885057471, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9693486590038314, 0.5, 'City.Population <= 177179.5\ngini = 0.375\nsamples = 6\nvalue = [6, 2]\nclass = Risky'),
#  Text(0.9616858237547893, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9770114942528736, 0.43333333333333335, 'City.Population <= 189345.0\ngini = 0.245\nsamples = 5\nvalue = [6, 1]\nclass = Risky'),
#  Text(0.9693486590038314, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.9846743295019157, 0.36666666666666664, 'City.Population <= 192727.0\ngini = 0.444\nsamples = 2\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.9770114942528736, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9923371647509579, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky')]
